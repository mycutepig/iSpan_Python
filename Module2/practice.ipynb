# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
price = 5000

if price > 2000:
    price -= 200

print(price)
# Out:
# 4800

# %%
# 滿 4000 折 400 滿 6000 折 600

price = 4000


print(price)
# Out:
# 3600
# 3400
